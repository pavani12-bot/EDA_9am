# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path=r"C:\Users\bhuma\Downloads\Visadataset.csv"
visa_df=pd.read_csv(file_path)

cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
# whenever you are identifed any mismatch
#the asme variable in showing one answer
# you are seing one answer
#immeditely you need to go to top and check that variable

# %% [markdown]
# **prevailing wage column**

# %%
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
pwage=visa_df['prevailing_wage']

# %%
min(pwage)
# Out:
# 2.1367

# %%
np.min(pwage)
# Out:
# 2.1367

# %%
pwage.min()
# Out:
# 2.1367

# %%
np.max(pwage)
# Out:
# 319210.27

# %%
np.mean(pwage)
# Out:
# np.float64(74455.81459209183)

# %%
np.median(pwage)
# Out:
# np.float64(70308.20999999999)

# %%
np.median(pwage)
# Out:
# np.float64(70308.20999999999)

# %%
len(pwage)
# Out:
# 25480

# %%
pwage.count()
# Out:
# np.int64(25480)

# %% [markdown]
# **percentile-quantile**

# %%
# 25 percentile value
np.percentile(pwage,25)
# Out:
# np.float64(34015.479999999996)

# %%
np.quantile(pwage,0.25)
# Out:
# np.float64(34015.479999999996)

# %%
np.quantile(pwage,25)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 np.quantile(pwage,25)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\_function_base_impl.py:4491, in quantile(a, q, axis, out, overwrite_input, method, keepdims, weights, interpolation)
#    4488     q = np.asanyarray(q)
#    4490 if not _quantile_is_valid(q):
# -> 4491     raise ValueError("Quantiles must be in the range [0, 1]")
#    4493 if weights is not None:
#    4494     if method != "inverted_cdf":
#
# ValueError: Quantiles must be in the range [0, 1]

# %%
np.percentile(pwage,50)

# %%
np.percentile(pwage,75)
# Out:
# np.float64(107735.51250000001)

# %%
pwage=visa_df['prevailing_wage']
count=pwage.count()
Min=np.min(pwage)
p_25=np.percentile(pwage,25)
mean=np.mean(pwage)
Median=np.median(pwage)
p_50=np.percentile(pwage,50)
p_75=np.percentile(pwage,75)
max=np.max(pwage)
metrics=[count,Min,p_25,mean,
         Median,p_50,p_75,max]
ID=['count','min','25%','mean',
    'median','50%','75%','max']
pd.DataFrame(metrics,index=ID,columns=[''])
# Out:
#
# count    25480.000000
# min          2.136700
# 25%      34015.480000
# mean     74455.814592
# median   70308.210000
# 50%      70308.210000
# 75%     107735.512500
# max     319210.270000

# %%
l=[]
for i in num:
    pwage=visa_df[i]
    count=pwage.count()
    Min=np.min(pwage)
    p_25=np.percentile(pwage,25)
    mean=np.mean(pwage)
    Median=np.median(pwage)
    p_50=np.percentile(pwage,50)
    p_75=np.percentile(pwage,75)
    max=np.max(pwage)
    metrics=[count,Min,p_25,mean,
             Median,p_50,p_75,max]
    l.append(metrics)
l
# Out:
# [[np.int64(25480),
#   -26,
#   np.float64(1022.0),
#   np.float64(5667.043210361067),
#   np.float64(2109.0),
#   np.float64(2109.0),
#   np.float64(3504.0),
#   602069],
#  [np.int64(25480),
#   1800,
#   np.float64(1976.0),
#   np.float64(1979.409929356358),
#   np.float64(1997.0),
#   np.float64(1997.0),
#   np.float64(2005.0),
#   2016],
#  [np.int64(25480),
#   2.1367,
#   np.float64(34015.479999999996),
#   np.float64(74455.81459209183),
#   np.float64(70308.20999999999),
#   np.float64(70308.20999999999),
#   np.float64(107735.51250000001),
#   319210.27]]

# %%
pd.DataFrame(l,index=num,columns=ID)
# Out:
#                  count        min       25%          mean    median       50%  \
# no_of_employees  25480   -26.0000   1022.00   5667.043210   2109.00   2109.00
# yr_of_estab      25480  1800.0000   1976.00   1979.409929   1997.00   1997.00
# prevailing_wage  25480     2.1367  34015.48  74455.814592  70308.21  70308.21
#
#                          75%        max
# no_of_employees    3504.0000  602069.00
# yr_of_estab        2005.0000    2016.00
# prevailing_wage  107735.5125  319210.27

# %%
visa_df.describe()
# Out:
#        no_of_employees   yr_of_estab  prevailing_wage
# count     25480.000000  25480.000000     25480.000000
# mean       5667.043210   1979.409929     74455.814592
# std       22877.928848     42.366929     52815.942327
# min         -26.000000   1800.000000         2.136700
# 25%        1022.000000   1976.000000     34015.480000
# 50%        2109.000000   1997.000000     70308.210000
# 75%        3504.000000   2005.000000    107735.512500
# max      602069.000000   2016.000000    319210.270000

# %% [markdown]
# **percentile**
#
#  - 25p = 34015.48
#
#    - there is a 25 percentage of total data has values less than wages 34015.48
#
# - what is the total data
#
#   - 25488
#
# - 25 percentage of total data
#
#   - 25480*25/100=6370
#
#   - there is a 6370 employees has wages less than 34015.48

# %%
# step-1 : total data : visadaf{pwage]
# step-2 : less than 25p 34015.48
# step-3 : create a condition
# step-4 : extract the true values visa_df[con]
pwage=visa_df['prevailing_wage']
p_25=np.percentile(pwage,25)
con=pwage<p_25
len(visa_df[con])==25480*25/100
# Out:
# True

# %% [markdown]
# **empirical rule**

# %%
# u-1*sigma  to  u+1*sigma  = 68
# step-1: means of wage
# step-2: std of wage
# step-3: lb=mean-1*sigma
#         lb= s1 - 1* s2
# step-4: ub=mean+1*sigma

# %%
wage_data=visa_df['prevailing_wage']
wage_mean=visa_df['prevailing_wage'].mean()
wage_std=visa_df['prevailing_wage'].std()
lb=wage_mean-1*wage_std
ub=wage_mean+1*wage_std
lb,ub
con1=wage_data>lb # u-1*sigma
con2=wage_data<ub # u+1*sigma
con=con1 & con2  # u-1*sigma to u+1*sigma
len(visa_df[con])==68*25480/100
# Out:
# False

# %%
68*25480/100
# Out:
# 17326.4

# %%
wage_data=visa_df['prevailing_wage']
wage_mean=visa_df['prevailing_wage'].mean()
wage_std=visa_df['prevailing_wage'].std()
lb=wage_mean-2*wage_std
ub=wage_mean+2*wage_std
lb,ub
con1=wage_data>lb # u-1*sigma
con2=wage_data<ub # u+1*sigma
con=con1 & con2  # u-1*sigma to u+1*sigma
len(visa_df[con])==95*25480/100
# Out:
# False

# %%
wage_data=visa_df['prevailing_wage']
wage_mean=visa_df['prevailing_wage'].mean()
wage_std=visa_df['prevailing_wage'].std()
lb=wage_mean-3*wage_std
ub=wage_mean+3*wage_std
lb,ub
con1=wage_data>lb # u-1*sigma
con2=wage_data<ub # u+1*sigma
con=con1 & con2  # u-1*sigma to u+1*sigma
len(visa_df[con])==99.7*25480/100
# Out:
# False

# %% [markdown]
# **empirical rule valid for normal distribution**
# **the above analysis concluded,data does not flow normality**

# %% [markdown]
# **histogram**

# %%
wage_data=visa_df['prevailing_wage']
plt.hist(wage_data)
# Out:
# (array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#           21.]),
#  array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#         1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#         2.55368643e+05, 2.87289457e+05, 3.19210270e+05]),
#  <BarContainer object of 10 artists>)

# %%
# for one interval we need two values
# 10 intervals so we need 11 values
# function returns 3 outputs
# count of each each interval#
#interval values
# no of intervals

# %%
wage_data=visa_df['prevailing_wage']
f,values,n=plt.hist(wage_data)

# %%
print(n)
# Out:
# <BarContainer object of 10 artists>

# %%
values
# Out:
# array([2.13670000e+00, 3.19229500e+04, 6.38437634e+04, 9.57645767e+04,
#        1.27685390e+05, 1.59606203e+05, 1.91527017e+05, 2.23447830e+05,
#        2.55368643e+05, 2.87289457e+05, 3.19210270e+05])

# %%
f
# Out:
# array([6038., 5504., 5681., 4551., 2334.,  624.,  373.,  240.,  114.,
#          21.])

# %%
# thera are 6038 applications has wages b\w 2.1367 to
2.13670000e+00,3.19229500e+04
# Out:
# (2.1367, 31922.95)

# %%
wage_data=visa_df['prevailing_wage']
lb=2.13670000e+00
ub=3.19229500e+04
con1=wage_data>=lb
con2=wage_data<=ub
con3=con1 & con2
len(visa_df[con3])
# Out:
# 6038

# %% [markdown]
# - we understand the **percentile**
#
# - we explore about ** emperical rule**
#
# - then **emperical rule** failed
#
# - that means the data does not follow **normal dist**
#
# - we also checked with **histogram plot**
#
# - histogram plot also supported our research : data does not follow **normality**
#
# - it has **right skew** ,sothat some outliers present
#
# - we need to visualize those **outliers** by using **boxplot**

# %%
plt.boxplot(wage_data,vert=False)
plt.show()

# %%
# step-1: cal q1
# step-2: cal q2
# step-3 : cal q3
# step-4 : iqr=q3-q1
 # step-5 lb=q1-1.5*iqr
# step-6 : ub=q3+1.5*iqr
# step-7: con1
#step-8 : con2
# step-9: con
# step-10 : get the count

# %%
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
iqr=q3-q1
lb=q1-1.5 * iqr
ub=q3+1.5 * iqr
con1=wage_data<lb
con2=wage_data>ub
con3=con1 |con2
outliers_df=visa_df[con3]
outliers_df['prevailing_wage'].values
outliers_list=outliers_df['prevailing_wage'].values.tolist()

# %%
# i want to call the each observation of wage data
# if that obs will avialable in this 427 values
# the obs will replace by median
# otherwise the ov=bs will be avialble
wage_median=visa_df['prevailing_wage'].median()
wage_data=visa_df['prevailing_wage']
new_wage_data=[]
for i in wage_data:
  if i in outliers_list:
    new_wage_data.append(wage_median)
else:
    new_wage_data.append(i)

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
plt.hist(wage_data)
plt.subplot(2,2,2)
plt.hist(new_wage_data)
plt.subplot(2,2,3)
plt.boxplot(wage_data,vert=False)
plt.subplot(2,2,4)
plt.boxplot(new_wage_data,vert=False)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1).hist(wage_data)
plt.subplot(2,2,2).hist(new_wage_data)
plt.subplot(2,2,3).boxplot(wage_data,vert=False)
plt.subplot(2,2,4).boxplot(new_wage_data,vert=False)
plt.show()

# %% [markdown]
# **vwinorization**
#
# - whatever the outliers less than lb fill with lb
#
# - whatever the outliers greater than ub fill with ub
#
# - in numpy we have method **clip**

# %%
# step-1 : get the wage data values
# step-2 : calculate lb
# step-3 : calculate ub
# step-4 : check the parameters and apply in numpy np.clip()
#s tep-5 : again implement above visualization analysis
wage_data=visa_df['prevailing_wage']
q1=np.percentile(wage_data,25)
q2=np.percentile(wage_data,50)
q3=np.percentile(wage_data,75)
iqr=q3-q1
lb=q1-1.5 * iqr
ub=q3+1.5 * iqr
wage_data_clip=np.clip(wage_data,lb,ub)

# %%
plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
plt.hist(wage_data)
plt.subplot(2,2,2)
plt.hist(wage_data_clip)
plt.subplot(2,2,3)
plt.boxplot(wage_data,vert=False)
plt.subplot(2,2,4)
plt.boxplot(wage_data_clip,vert=False)
plt.show()
